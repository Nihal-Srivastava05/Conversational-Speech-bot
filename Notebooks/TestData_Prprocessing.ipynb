# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../Dataset/isl_wise_train_detail_03082015_v1.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69006 entries, 0 to 69005
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Train No.                 69006 non-null  object
#  1   train Name                69006 non-null  object
#  2   islno                     69006 non-null  int64
#  3   station Code              69006 non-null  object
#  4   Station Name              69006 non-null  object
#  5   Arrival time              69006 non-null  object
#  6   Departure time            69006 non-null  object
#  7   Distance                  69006 non-null  int64
#  8   Source Station Code       69006 non-null  object
#  9   source Station Name       69006 non-null  object
#  10  Destination station Code  69006 non-null  object
#  11  Destination Station Name  69006 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 6.3+ MB

# %%
df
# Out:
#       Train No.       train Name  islno station Code     Station Name  \
# 0       '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 1       '00851'  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
# 2       '00851'  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
# 3       '00851'  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4       '00851'  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
# ...         ...              ...    ...          ...              ...
# 69001   '84369'  TRIBENI EXPRESS     35         LKO   LUCKNOW NR
# 69002   '84369'  TRIBENI EXPRESS     36         SAN   SANDILA
# 69003   '84369'  TRIBENI EXPRESS     37         HRI   HARDOI
# 69004   '84369'  TRIBENI EXPRESS     38         SPN   SHAHJEHANPUR
# 69005   '84369'  TRIBENI EXPRESS     39         BE    BAREILLY
#
#       Arrival time Departure time  Distance Source Station Code  \
# 0       '00:00:00'     '22:50:00'         0                BBS
# ...

# %%
df.drop(columns=["Train No.","train Name","islno","station Code","Distance","Source Station Code","Destination station Code"], inplace = True)

# %%
df.isnull().sum()
# Out:
# Station Name                0
# Arrival time                0
# Departure time              0
# source Station Name         0
# Destination Station Name    0
# dtype: int64

# %%
df
# Out:
#           Station Name Arrival time Departure time source Station Name  \
# 0      BHUBANESWAR       '00:00:00'     '22:50:00'     BHUBANESWAR
# 1      BRAHMAPUR         '01:10:00'     '01:12:00'     BHUBANESWAR
# 2      VISAKHAPATNAM     '05:10:00'     '05:30:00'     BHUBANESWAR
# 3      VIJAYAWADA JN     '11:10:00'     '11:20:00'     BHUBANESWAR
# 4      RENIGUNTA JN      '16:42:00'     '16:52:00'     BHUBANESWAR
# ...                ...          ...            ...                 ...
# 69001  LUCKNOW NR        '08:35:00'     '08:45:00'     BARWADIH JN
# 69002  SANDILA           '09:34:00'     '09:35:00'     BARWADIH JN
# 69003  HARDOI            '10:19:00'     '10:20:00'     BARWADIH JN
# 69004  SHAHJEHANPUR      '11:25:00'     '11:30:00'     BARWADIH JN
# 69005  BAREILLY          '12:35:00'     '00:00:00'     BARWADIH JN
#
#       Destination Station Name
# 0              BANGALORE CANT
# 1              BANGALORE CANT
# 2              BANGALORE CANT
# ...

# %%
df.to_csv('../Dataset/train.csv')
